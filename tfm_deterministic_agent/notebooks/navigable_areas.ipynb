# %% [markdown]
# # Imports

# %%
import folium
from folium.plugins import Draw, MarkerCluster

# %%
import sys
import os
from pathlib import Path
import pandas as pd
import networkx as nx
import json
# Opciones de visualización
import matplotlib.pyplot as plt

# %%
# Aseguramos que el directorio raíz del proyecto esté en el path
#project_root = Path().resolve().parent  # Ajusta si es necesario
#if str(project_root) not in sys.path:
#    sys.path.insert(0, str(project_root))

# Obtener ruta absoluta del directorio que contiene el notebook
notebook_dir = os.path.dirname(os.getcwd())  # sube un nivel desde /notebook
if notebook_dir not in sys.path:
    sys.path.append(notebook_dir)

# %% [markdown]
# # Selecionar Area

# %%
lat, lon, zoom = 40.35, 0.40, 10
m = folium.Map(location=[lat, lon], zoom_start=zoom, tiles='OpenStreetMap')

folium.TileLayer(
    tiles='https://tiles.openseamap.org/seamark/{z}/{x}/{y}.png',
    attr='© OpenSeaMap contributors',
    name='Seamarks',
    overlay=True,
    control=True
).add_to(m)

folium.raster_layers.WmsTileLayer(
    url='https://ows.emodnet-bathymetry.eu/wms?',
    layers='emodnet:contours',
    fmt='image/png',
    transparent=True,
    version='1.3.0',
    attr='© EMODnet Bathymetry',
    name='Contornos (EMODnet)',
    overlay=True,
    control=True,
    opacity=1.0
).add_to(m)

draw = Draw(
    export=True,
    filename='selection.geojson',
    position='topright',
    draw_options={
        'polyline': False,
        'polygon': False,
        'circle': False,
        'marker': False,
        'circlemarker': False,
        'rectangle': True,
    },
    edit_options={'edit': False}
)
draw.add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e92aef20cc4a4e0649820af6d7799eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e92aef20cc4a4e0649820af6d7799eb&quot; &gt;&lt;/div&gt;
#
#
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#             &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e92aef20cc4a4e0649820af6d7799eb = L.map(
#                 &quot;map_4e92aef20cc4a4e0649820af6d7799eb&quot;,
#                 {
#                     center: [40.35, 0.4],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af076b0cf5b5bcfc79bd45fc975237a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af076b0cf5b5bcfc79bd45fc975237a1.addTo(map_4e92aef20cc4a4e0649820af6d7799eb);
#
#
#             var tile_layer_6816c752d3c16a3e278ecfc5ce8dec6f = L.tileLayer(
#                 &quot;https://tiles.openseamap.org/seamark/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 OpenSeaMap contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6816c752d3c16a3e278ecfc5ce8dec6f.addTo(map_4e92aef20cc4a4e0649820af6d7799eb);
#
#
#             var macro_element_28af41d8c847d654a8f2074d5d67a3ab = L.tileLayer.wms(
#                 &quot;https://ows.emodnet-bathymetry.eu/wms?&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 EMODnet Bathymetry&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;emodnet:contours&quot;, &quot;opacity&quot;: 1.0, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.3.0&quot;}
#             );
#
#
#             macro_element_28af41d8c847d654a8f2074d5d67a3ab.addTo(map_4e92aef20cc4a4e0649820af6d7799eb);
#
#
#             var options = {
#               position: &quot;topright&quot;,
#               draw: {&quot;circle&quot;: false, &quot;circlemarker&quot;: false, &quot;marker&quot;: false, &quot;polygon&quot;: false, &quot;polyline&quot;: false, &quot;rectangle&quot;: true},
#               edit: {&quot;edit&quot;: false},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_91d2d4e235f496474724f7c2170ea845 =
#                     new L.featureGroup().addTo(
#                         map_4e92aef20cc4a4e0649820af6d7799eb
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_91d2d4e235f496474724f7c2170ea845;
#             var draw_control_91d2d4e235f496474724f7c2170ea845 = new L.Control.Draw(
#                 options
#             ).addTo( map_4e92aef20cc4a4e0649820af6d7799eb );
#             map_4e92aef20cc4a4e0649820af6d7799eb.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_91d2d4e235f496474724f7c2170ea845.addLayer(layer);
#             });
#             map_4e92aef20cc4a4e0649820af6d7799eb.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_91d2d4e235f496474724f7c2170ea845.addLayer(e.layer);
#             });
#
#
#             document.getElementById(&#x27;export&#x27;).onclick = function(e) {
#                 var data =

# %% [markdown]
# # Cargar zona de estudio

# %%
from generate_area.select_area import get_area_bounds

path_geojson = os.path.join("..", "..", "data", "raw", "selection_1.geojson")

# %%
# 2) Obtener límites
lat_min, lat_max, lon_min, lon_max = get_area_bounds(path_geojson)
print(f"lat_min = {lat_min:.6f}, lat_max = {lat_max:.6f}")
print(f"lon_min = {lon_min:.6f}, lon_max = {lon_max:.6f}")
# Out:
# lat_min = 37.865320, lat_max = 40.651460
# lon_min = -0.098924, lon_max = 5.156147

# %% [markdown]
# # Generar malla

# %%
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from generate_area.generate_meh import generate_mesh_mercator

# %%
# 2.1 – Parámetros de la malla
paso_lon = 0.042   # espaciado en longitud (°)
N_lat    = 50      # número de intervalos en latitud

# %%
# 2.2 – Generar lista de puntos (lat, lon)
puntos_malla = generate_mesh_mercator(
    lat_min, lat_max,
    lon_min, lon_max,
    paso_lon,
    N_lat
)

# %%
# 2.3 – Crear GeoDataFrame de nodos
mesh_gdf = gpd.GeoDataFrame(
    {
        'latitude': [pt[0] for pt in puntos_malla],
        'longitude': [pt[1] for pt in puntos_malla]
    },
    geometry=[Point(lon, lat) for lat, lon in puntos_malla],
    crs='EPSG:4326'
)

print(f"Total nodos generados: {len(mesh_gdf)}")
# Out:
# Total nodos generados: 5355

# %% [markdown]
# ## Visualizacion de malla

# %%
# 1) Centrar el mapa en el área de estudio
center_lat = (lat_min + lat_max) / 2
center_lon = (lon_min + lon_max) / 2
m = folium.Map(location=[center_lat, center_lon], zoom_start=9)

# 2) Capa de símbolos náuticos (OpenSeaMap)
folium.TileLayer(
    tiles='https://tiles.openseamap.org/seamark/{z}/{x}/{y}.png',
    attr='© OpenSeaMap contributors',
    name='Seamarks',
    overlay=True,
    control=True
).add_to(m)

# 3) Capa de contornos batimétricos (EMODnet)
folium.raster_layers.WmsTileLayer(
    url='https://ows.emodnet-bathymetry.eu/wms?',
    layers='emodnet:contours',
    fmt='image/png',
    transparent=True,
    version='1.3.0',
    attr='© EMODnet Bathymetry',
    name='Contornos (EMODnet)',
    overlay=True,
    control=True,
    opacity=0.7
).add_to(m)

# 4) Dibujar cada nodo de la malla como un CircleMarker
for _, row in mesh_gdf.iterrows():
    folium.CircleMarker(
        location=(row.latitude, row.longitude),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        weight=0
    ).add_to(m)

# 5) Control de capas
folium.LayerControl().add_to(m)

# 6) Mostrar el mapa (en Jupyter se renderiza automáticamente)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9a63721d013e90852a2e41264d14071 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9a63721d013e90852a2e41264d14071&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9a63721d013e90852a2e41264d14071 = L.map(
#                 &quot;map_f9a63721d013e90852a2e41264d14071&quot;,
#                 {
#                     center: [37.6213665, 13.853759499999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_451dd4716b5e2d5d03ce971b906f8956 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_451dd4716b5e2d5d03ce971b906f8956.addTo(map_f9a63721d013e90852a2e41264d14071);
#
#
#             var tile_layer_5a3c42e14199708c9f420ec47f2f33a5 = L.tileLayer(
#                 &quot;https://tiles.openseamap.org/seamark/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 OpenSeaMap contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a3c42e14199708c9f420ec47f2f33a5.addTo(map_f9a63721d013e90852a2e41264d14071);
#
#
#             var macro_element_22e5d2d004cfa3e9d43e046935072c5c = L.tileLayer.wms(
#                 &quot;https://ows.emodnet-bathymetry.eu/wms?&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 EMODnet Bathymetry&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;emodnet:contours&quot;, &quot;opacity&quot;: 0.7, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.3.0&quot;}
#             );
#
#
#             macro_element_22e5d2d004cfa3e9d43e046935072c5c.addTo(map_f9a63721d013e90852a2e41264d14071);
#
#
#             var circle_marker_3582cec2009ee7f0e367df2524ffb384 = L.circleMarker(
#                 [36.38591299999999, 11.66748],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_f9a63721d013e90852a2e41264d14071);
#
#
#             var circle_marker_b880c5501404071f6cabafc4c0aeccf1 = L.circleMarker(
#                 [36.38591299999999, 11.70948],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_f9a63721d013e90852a2e41264d14071);
#
#
#             var circle_marker_03d65f34474078acaf490437c5489f3d = L.circleMarker(
#                 [36.38591299999999, 11.751479999999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_f9a63721d013e90852a2e41264d14071);
#
#
#             var circle_marker_0ccc12bfae48cfd75f3f8815782c1641 = L.circleMarker(
#                 [36.38591299999999, 11.793479999999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 0}

# %% [markdown]
# # Obtener profundidades

# %%
import pandas as pd
from generate_area.depht_data_meh import batch_evaluate_navigability

# %%
# 3.1 – Parámetro de calado mínimo de la embarcación (en metros)
draft = 2.0

# 3.2 – Llamada al batch para obtener depth_avg y flag navigable
bathy_results = batch_evaluate_navigability(
    [(row.latitude, row.longitude) for _, row in mesh_gdf.iterrows()],
    draft
)

# %%
# 3.3 – Convertir a DataFrame
df_bathy = pd.DataFrame(bathy_results)

# 3.4 – Unir con la malla original para conservar geometría
bathy_gdf = mesh_gdf.merge(df_bathy, on=['latitude', 'longitude'])

# 3.5 – Exportar resultados
df_bathy.to_csv('../../data/raw/malla/nodes_bathy.csv', index=False)

# %%
# (Opcional) Mostrar resumen
print(f"Nodos totales: {len(bathy_gdf)}")
print(f"Nodos navegables: {bathy_gdf['navigable'].sum()}")
# Out:
# Nodos totales: 5355
# Nodos navegables: 3965

# %% [markdown]
# ## Validación

# %%
import pandas as pd

# Cargar el CSV unificado
df = pd.read_csv('../../data/raw/malla/nodes_bathy.csv')

# 1) Resumen de valores nulos por columna
print("Valores nulos por columna:")
print(df.isna().sum())
# Out:
# Valores nulos por columna:
# latitude     0
# longitude    0
# depth_avg    0
# navigable    0
# dtype: int64

# %% [markdown]
# # Obtener vientos

# %%
import pandas as pd
from generate_area.wind_data_meh import batch_evaluate_wind

# %%
# 4.1 – Cargar resultados de batimetría
df_bathy = pd.read_csv('../../data/raw/malla/nodes_bathy.csv')

# %%
# 4.2 – Definir parámetros de tu barco y periodo de interés
boat_data = {
    'max_wind_speed': 25.0,   # umbral en nudos
    # ...otros parámetros (e.g. polar, calado) si los requiere batch_evaluate_wind
}
start_date = '2025-06-01'
end_date   = '2025-06-01'

# %%
# 4.3 – Ejecutar batch para nodos navegables
wind_results = batch_evaluate_wind(
    df_bathy.to_dict(orient='records'),
    boat_data,
    start_date,
    end_date
)

# %%
# 4.4 – Crear DataFrame de resultados de viento
df_wind = pd.DataFrame(wind_results)

# 4.5 – Unir con batimetría para mantener todos los campos
df_bathy_wind = df_bathy.merge(
    df_wind[['latitude','longitude','time','wind_speed_10m','wind_direction_10m','navigable']],
    on=['latitude','longitude'],
    suffixes=('','_wind')
)

# %%
# 4.6 – Guardar salida
df_bathy_wind.to_csv('../../data/raw/malla/nodes_bathy_wind.csv', index=False)

# %% [markdown]
# ## Validación

# %%
import pandas as pd

# Cargar el CSV unificado
df = pd.read_csv('../../data/raw/malla/nodes_bathy_wind.csv')

# 1) Resumen de valores nulos por columna
print("Valores nulos por columna:")
print(df.isna().sum())
# Out:
# Valores nulos por columna:
# latitude              0
# longitude             0
# depth_avg             0
# navigable             0
# time                  0
# wind_speed_10m        0
# wind_direction_10m    0
# navigable_wind        0
# dtype: int64

# %% [markdown]
# # Obtenemos los obstaculos

# %%
import pandas as pd
import json
from shapely.ops import unary_union
from shapely.geometry import mapping
from generate_area.nautical_constraints_meh import (
    load_forbidden_zones,
    mark_blocked_seamark,
    fetch_seamark_elements,
    fetch_coastline_elements,
    classify_seamarks,
    create_buoy_nodes,
    combine_mesh_and_buoys,
    compute_navigable_final
)

# %%
# 5.1 – Cargar resultados de batimetría + viento
df_bw = pd.read_csv('../../data/raw/malla/nodes_bathy_wind.csv')

# %%
# 5.2 – Cargar zonas prohibidas (seamarks + línea de costa)
tree = load_forbidden_zones(lat_min, lon_min, lat_max, lon_max, seguridad=0.01)
restricted_geoms = list(tree.geometries)

# 5.3 – Marcar los nodos bloqueados por seamarks/costa
df_bw['blocked_seamark'] = mark_blocked_seamark(df_bw, restricted_geoms, seguridad=0.01)

# 5.4 – Clasificar y crear nodos de boya
elements     = fetch_seamark_elements(lat_min, lon_min, lat_max, lon_max)
buoy_geoms   = classify_seamarks(elements)
buoy_df      = create_buoy_nodes(buoy_geoms)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 11
#       9 elements     = fetch_seamark_elements(lat_min, lon_min, lat_max, lon_max)
#      10 buoy_geoms   = classify_seamarks(elements)
# ---> 11 buoy_df      = create_buoy_nodes(buoy_geoms)
#
# File c:\Users\aigut\OneDrive\Documentos\Sailing-route-generator-for-sailboats\tfm_deterministic_agent\generate_area\nautical_constraints_meh.py:161, in create_buoy_nodes(buoy_geoms)
#     159         pt = shape(b['geometry'])
#     160     else:
# --> 161         raise ValueError(f"Tipo no soportado en buoy_geoms: {type(b)}")
#     163     rows.append({
#     164         'latitude': pt.y,
#     165         'longitude': pt.x,
#    (...)    172         'is_buoy': True
#     173     })
#     175 return pd.DataFrame(rows)
#
# ValueError: Tipo no soportado en buoy_geoms: <class 'shapely.geometry.linestring.LineString'>

# %%
# 6 – Unificar todos los datos y computar navegabilidad final
nodes_df = combine_mesh_and_buoys(df_bw, buoy_df)
nodes_df['navigable_final'] = compute_navigable_final(nodes_df)
nodes_df.to_csv('../../data/raw/malla1/nodes_unified.csv', index=False)
# Out:
# c:\Users\aigut\OneDrive\Documentos\Sailing-route-generator-for-sailboats\tfm_deterministic_agent\generate_area\nautical_constraints_meh.py:183: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat([mesh_df, buoy_df], ignore_index=True, sort=False)

# %%
# 7 – Exportar zonas no navegables a GeoJSON
# Unir todos los polígonos de restricted_geoms en un único MultiPolygon
union_poly = unary_union(restricted_geoms)
# Crear FeatureCollection
features = [
    {"type":"Feature", "geometry": mapping(poly)}
    for poly in (union_poly.geoms if hasattr(union_poly, "geoms") else [union_poly])
]
with open('../../data/raw/malla/non_navigable_zones.json', 'w') as f:
    json.dump({"type":"FeatureCollection", "features": features}, f)

# %% [markdown]
# # Calculo de grafo ponderado

# %%
import pandas as pd
import json
import pickle
from shapely.geometry import shape, MultiPolygon
from generate_area.build_graph import build_weighted_graph

# %%
# 8.1 – Cargar ficheros de entrada
nodes_df   = pd.read_csv('../../data/raw/malla/nodes_unified.csv')
polar_df   = pd.read_csv('../../data/raw/malla/polar_diagram.csv')
with open('../../data/raw/malla/non_navigable_zones.json', 'r', encoding='utf-8') as f:
    zones_fc = json.load(f)

# %%
# 8.2 – Construir la geometría unida de zonas no navegables
geoms = [shape(feat['geometry']) for feat in zones_fc['features']]
if len(geoms) > 1:
    union_restr = MultiPolygon(geoms)
else:
    union_restr = geoms[0]

# 8.3 – Crear el grafo dirigido ponderado
G = build_weighted_graph(
    nodes_df,
    polar_df,
    union_restr,
    max_neighbors=32,
    neighbor_cells=3,
    alpha_time=1.0,
    beta_comfort=0.1
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 9
#       6     union_restr = geoms[0]
#       8 # 8.3 – Crear el grafo dirigido ponderado
# ----> 9 G = build_weighted_graph(
#      10     nodes_df,
#      11     polar_df,
#      12     union_restr,
#      13     max_neighbors=32,
#      14     neighbor_cells=3,
#      15     alpha_time=1.0,
#      16     beta_comfort=0.1
#      17 )
#
# File c:\Users\aigut\OneDrive\Documentos\Sailing-route-generator-for-sailboats\tfm_deterministic_agent\generate_area\build_graph.py:151, in build_weighted_graph(nodes_df, polar_df, union_restr, max_neighbors, neighbor_cells, alpha_time, beta_comfort)
#     147 brg_true = bearing(lon_u, lat_u,
#     148                    G.nodes[best_v]['longitude'],
#     149                    G.nodes[best_v]['latitude'])
#     150 twa = abs(brg_true - Dw)
# --> 151 boat_speed = polar.get_speed(twa)
#     152 if boat_speed <= 0:
#     153     continue
#
# File c:\Users\aigut\OneDrive\Documentos\Sailing-route-generator-for-sailboats\tfm_deterministic_agent\generate_area\build_graph.py:45, in PolarDiagram.get_speed(self, twa)
#      43 if twa >= df['TWA'].iloc[-1]:
#      44     return df['Speed'].iloc[-1]
# ---> 45 lower = df[df['TWA'] <= twa].iloc[-1]
#      46 upper = df[df['TWA'] >= twa].iloc[0]
#      47 if lower['TWA'] == upper['TWA']:
#
# File c:\Users\aigut\OneDrive\Documentos\Sailing-route-generator-for-sailboats\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\aigut\OneDrive\Documentos\Sailing-route-generator-for-sailboats\.venv\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\aigut\OneDrive\Documentos\Sailing-route-generator-for-sailboats\.venv\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
# 8.4 – Guardar el grafo para uso posterior
with open('../../data/raw/malla/weighted_graph.pkl', 'wb') as f:
    pickle.dump(G, f)

print(f"Grafo creado: {G.number_of_nodes()} nodos, {G.number_of_edges()} aristas")

# %% [markdown]
# ## Visualización de grafo
